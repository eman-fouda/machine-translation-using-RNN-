# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, SimpleRNN
from tensorflow.keras.layers import Flatten

# %%
num_words = 10000
maxlen = 100
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=num_words)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
model = Sequential()
model.add(Embedding(num_words, 32, input_length=maxlen))
model.add(SimpleRNN(32, return_sequences=True))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 157/157 [==============================] - 43s 239ms/step - loss: 0.4673 - accuracy: 0.7604 - val_loss: 0.3599 - val_accuracy: 0.8442
# Epoch 2/10
# 157/157 [==============================] - 29s 184ms/step - loss: 0.2377 - accuracy: 0.9062 - val_loss: 0.3758 - val_accuracy: 0.8406
# Epoch 3/10
# 157/157 [==============================] - 23s 146ms/step - loss: 0.1103 - accuracy: 0.9603 - val_loss: 0.5317 - val_accuracy: 0.8222
# Epoch 4/10
# 157/157 [==============================] - 20s 128ms/step - loss: 0.0266 - accuracy: 0.9916 - val_loss: 0.8328 - val_accuracy: 0.8264
# Epoch 5/10
# 157/157 [==============================] - 21s 136ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.9186 - val_accuracy: 0.8146
# Epoch 6/10
# 157/157 [==============================] - 20s 126ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 1.1179 - val_accuracy: 0.8198
# Epoch 7/10
# 157/157 [==============================] - 20s 130ms/step - loss: 9.5339e-04 - accuracy: 0.9998 - val_loss: 1.2045 - val_accuracy: 0.8204
# Epoch 8/10
# 157/157 [==============================] - 20s 130ms/step - loss: 1.3852e-04 - accuracy: 1.0000 - val_loss: 1.2836 - val_accuracy: 0.8204
# Epoch 9/10
# 157/157 [==============================] - 19s 122ms/step - loss: 5.3868e-05 - accuracy: 1.0000 - val_loss: 1.3361 - val_accuracy: 0.8220
# Epoch 10/10
# 157/157 [==============================] - 20s 126ms/step - loss: 3.4420e-05 - accuracy: 1.0000 - val_loss: 1.3703 - val_accuracy: 0.8222

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 782/782 [==============================] - 11s 14ms/step - loss: 1.4292 - accuracy: 0.8211
# Test Accuracy: 0.8210800290107727
